# %% [markdown]
# # Clustering and Dimensionality Reduction Exam
# Welcome to the weekly project on clustering and dimensionality reduction. You will be working with a dataset of traffic accidents.
#
# ## Dataset
# The dataset that will be used in this task is `Traffic_Accidents.csv`
#
# ## Instructions
# - Follow the steps outlined below.
# - Write your code in the empty code cells.
# - Comment on your code to explain your reasoning.
#
# ## Dataset Overview
# The dataset contains information about traffic accidents, including location, weather conditions, road conditions, and more. Below are sample of these columns:
#
# * `Location_Easting_OSGR`: Easting coordinate of the accident location.
# * `Location_Northing_OSGR`: Northing coordinate of the accident location.
# * `Longitude`: Longitude of the accident site.
# * `Latitude`: Latitude of the accident site.
# * `Police_Force`: Identifier for the police force involved.
# * `Accident_Severity`: Severity of the accident.
# * `Number_of_Vehicles`: Number of vehicles involved in the accident.
# * `Number_of_Casualties`: Number of casualties in the accident.
# * `Date`: Date of the accident.
# * `Day_of_Week`: Day of the week when the accident occurred.
# * `Speed_limit`: Speed limit in the area where the accident occurred.
# * `Weather_Conditions`: Weather conditions at the time of the accident.
# * `Road_Surface_Conditions`: Condition of the road surface during the accident.
# * `Urban_or_Rural_Area`: Whether the accident occurred in an urban or rural area.
# * `Year`: Year when the accident was recorded.
# * Additional attributes related to road type, pedestrian crossing, light conditions, etc.
#
# ## Goal
# The primary goal is to analyze the accidents based on their geographical location.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# %% [markdown]
# ## Load the Data

# %%
df = pd.read_csv('/content/Traffic_Accidents.csv')
df
# Out:
#        Location_Easting_OSGR  Location_Northing_OSGR  Longitude   Latitude  \
# 0                   560530.0                103950.0   0.277298  50.812789
# 1                   508860.0                187170.0  -0.430574  51.572846
# 2                   314460.0                169130.0  -3.231459  51.414661
# 3                   341700.0                408330.0  -2.881800  53.568318
# 4                   386488.0                350090.0  -2.203020  53.047882
# ...                      ...                     ...        ...        ...
# 51995               475125.0                319380.0  -0.888006  52.766777
# 51996               456682.0                127058.0  -1.192915  51.040030
# 51997               540510.0                152250.0   0.012032  51.252055
# 51998               434720.0                334000.0  -1.485264  52.902301
# 51999               454710.0                185430.0  -1.212104  51.565050
#
#        Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0                47                3.0                   1
# 1                 1                3.0                   2
# 2                62                3.0                   2
# 3                 4                3.0                   1
# 4                21                3.0                   2
# ...             ...                ...                 ...
# 51995            33                3.0                   2
# 51996            44                3.0                   1
# 51997            45                3.0                   3
# 51998            30                3.0                   2
# 51999            43                3.0                   3
#
#        Number_of_Casualties        Date  Day_of_Week  ...  2nd_Road_Class  \
# 0                       1.0  27/11/2009            6  ...              -1
# 1                       1.0  10/10/2010            1  ...               6
# 2                       1.0  14/09/2005            4  ...               3
# 3                       2.0  18/08/2007            7  ...               6
# 4                       2.0  06/08/2013            3  ...              -1
# ...                     ...         ...          ...  ...             ...
# 51995                   1.0  31/08/2012            6  ...               6
# 51996                   1.0  08/05/2013            4  ...              -1
# 51997                   1.0  01/11/2011            3  ...               6
# 51998                   2.0  22/07/2011            6  ...               5
# 51999                   1.0  24/05/2010            2  ...              -1
#
#       2nd_Road_Number  Pedestrian_Crossing-Human_Control  \
# 0                   0              None within 50 metres
# 1                   0              None within 50 metres
# 2                4055              None within 50 metres
# 3                   0              None within 50 metres
# 4                   0              None within 50 metres
# ...               ...                                ...
# 51995            6485              None within 50 metres
# 51996               0              None within 50 metres
# 51997               0              None within 50 metres
# 51998              81              None within 50 metres
# 51999               0              None within 50 metres
#
#            Pedestrian_Crossing-Physical_Facilities  \
# 0            No physical crossing within 50 meters
# 1            No physical crossing within 50 meters
# 2            No physical crossing within 50 meters
# 3            No physical crossing within 50 meters
# 4            No physical crossing within 50 meters
# ...                                            ...
# 51995  Pedestrian phase at traffic signal junction
# 51996        No physical crossing within 50 meters
# 51997        No physical crossing within 50 meters
# 51998        No physical crossing within 50 meters
# 51999        No physical crossing within 50 meters
#
#                               Light_Conditions          Weather_Conditions  \
# 0                Darkeness: No street lighting     Raining with high winds
# 1      Darkness: Street lights present and lit     Fine without high winds
# 2               Daylight: Street light present     Fine without high winds
# 3               Daylight: Street light present  Raining without high winds
# 4               Daylight: Street light present     Fine without high winds
# ...                                        ...                         ...
# 51995           Daylight: Street light present     Fine without high winds
# 51996            Darkeness: No street lighting     Fine without high winds
# 51997           Daylight: Street light present  Raining without high winds
# 51998           Daylight: Street light present  Raining without high winds
# 51999           Daylight: Street light present     Fine without high winds
#
#          Road_Surface_Conditions  Urban_or_Rural_Area  \
# 0      Flood (Over 3cm of water)                  2.0
# 1                            Dry                  1.0
# 2                            Dry                  1.0
# 3                       Wet/Damp                  1.0
# 4                            Dry                  1.0
# ...                          ...                  ...
# 51995                        Dry                  1.0
# 51996                        Dry                  2.0
# 51997                   Wet/Damp                  1.0
# 51998                   Wet/Damp                  1.0
# 51999                        Dry                  2.0
#
#       Did_Police_Officer_Attend_Scene_of_Accident  Year
# 0                                             Yes  2009
# 1                                             Yes  2010
# 2                                             Yes  2005
# 3                                             Yes  2007
# 4                                             Yes  2013
# ...                                           ...   ...
# 51995                                         Yes  2012
# 51996                                         Yes  2013
# 51997                                         Yes  2011
# 51998                                         Yes  2011
# 51999                                         Yes  2010
#
# [52000 rows x 26 columns]

# %%
df.shape
# Out:
# (52000, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52000 entries, 0 to 51999
# Data columns (total 26 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Location_Easting_OSGR                        52000 non-null  float64
#  1   Location_Northing_OSGR                       52000 non-null  float64
#  2   Longitude                                    52000 non-null  float64
#  3   Latitude                                     52000 non-null  float64
#  4   Police_Force                                 52000 non-null  int64
#  5   Accident_Severity                            51678 non-null  float64
#  6   Number_of_Vehicles                           52000 non-null  int64
#  7   Number_of_Casualties                         50959 non-null  float64
#  8   Date                                         52000 non-null  object
#  9   Day_of_Week                                  52000 non-null  int64
#  10  Local_Authority_(District)                   52000 non-null  int64
#  11  Local_Authority_(Highway)                    52000 non-null  object
#  12  1st_Road_Class                               52000 non-null  int64
#  13  1st_Road_Number                              52000 non-null  int64
#  14  Road_Type                                    52000 non-null  object
#  15  Speed_limit                                  52000 non-null  int64
#  16  2nd_Road_Class                               52000 non-null  int64
#  17  2nd_Road_Number                              52000 non-null  int64
#  18  Pedestrian_Crossing-Human_Control            52000 non-null  object
#  19  Pedestrian_Crossing-Physical_Facilities      52000 non-null  object
#  20  Light_Conditions                             51456 non-null  object
#  21  Weather_Conditions                           52000 non-null  object
#  22  Road_Surface_Conditions                      52000 non-null  object
#  23  Urban_or_Rural_Area                          51912 non-null  float64
#  24  Did_Police_Officer_Attend_Scene_of_Accident  52000 non-null  object
#  25  Year                                         52000 non-null  int64
# dtypes: float64(7), int64(10), object(9)
# memory usage: 10.3+ MB

# %%
df.describe()
# Out:
#        Location_Easting_OSGR  Location_Northing_OSGR     Longitude  \
# count           52000.000000            5.200000e+04  52000.000000
# mean           440284.256846            2.998617e+05     -1.427193
# std             95109.751221            1.613624e+05      1.398249
# min             98480.000000            1.903000e+04     -6.895268
# 25%            375540.000000            1.780100e+05     -2.366190
# 50%            440950.000000            2.671800e+05     -1.391202
# 75%            523500.000000            3.981492e+05     -0.214666
# max            654960.000000            1.203900e+06      1.753632
#
#            Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# count  52000.000000  52000.000000       51678.000000        52000.000000
# mean      52.586684     30.401712           2.837145            1.834327
# std        1.453049     25.545581           0.402582            0.727856
# min       50.026153      1.000000           1.000000            1.000000
# 25%       51.487676      7.000000           3.000000            1.000000
# 50%       52.295042     30.000000           3.000000            2.000000
# 75%       53.478016     46.000000           3.000000            2.000000
# max       60.714774     98.000000           3.000000           34.000000
#
#        Number_of_Casualties   Day_of_Week  Local_Authority_(District)  \
# count          50959.000000  52000.000000                52000.000000
# mean               1.354756      4.130712                  349.542558
# std                0.855220      1.926217                  259.504721
# min                1.000000      1.000000                    1.000000
# 25%                1.000000      2.000000                  112.000000
# 50%                1.000000      4.000000                  323.000000
# 75%                1.000000      6.000000                  530.000000
# max               51.000000      7.000000                  941.000000
#
#        1st_Road_Class  1st_Road_Number   Speed_limit  2nd_Road_Class  \
# count    52000.000000     52000.000000  52000.000000    52000.000000
# mean         4.080519       997.078077     39.148558        2.672673
# std          1.428056      1806.405065     14.212826        3.205080
# min          1.000000         0.000000     15.000000       -1.000000
# 25%          3.000000         0.000000     30.000000       -1.000000
# 50%          4.000000       128.500000     30.000000        3.000000
# 75%          6.000000       716.000000     50.000000        6.000000
# max          6.000000      9999.000000     70.000000        6.000000
#
#        2nd_Road_Number  Urban_or_Rural_Area          Year
# count     52000.000000         51912.000000  52000.000000
# mean        384.503058             1.359397   2009.401788
# std        1304.989395             0.479868      3.006997
# min          -1.000000             1.000000   2005.000000
# 25%           0.000000             1.000000   2006.000000
# 50%           0.000000             1.000000   2010.000000
# 75%           0.000000             2.000000   2012.000000
# max        9999.000000             3.000000   2014.000000

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
# Perform EDA to understand the data better. This involves several steps to summarize the main characteristics, uncover patterns, and establish relationships:
# * Find the dataset information and observe the datatypes.
# * Check the shape of the data to understand its structure.
# * View the the data with various functions to get an initial sense of the data.
# * Perform summary statistics on the dataset to grasp central tendencies and variability.
# * Check for duplicated data.
# * Check for null values.
#
# And apply more if needed!

# %%
import pandas as pd

data = pd.read_csv('/content/Traffic_Accidents.csv')

print("Dataset Information:")
print(data.info())

print("\nDataset Shape:")
print(data.shape)

print("\nFirst Few Rows of the Dataset:")
print(data.head())

print("\nLast Few Rows of the Dataset:")
print(data.tail())

print("\nRandom Sample of Rows:")
print(data.sample(5))

print("\nSummary Statistics (Numerical):")
print(data.describe())

print("\nSummary Statistics (Categorical):")
print(data.describe(include=['O']))

duplicates = data.duplicated().sum()
print(f"\nNumber of Duplicated Rows: {duplicates}")

if duplicates > 0:
    print("\nDuplicated Rows:")
    print(data[data.duplicated()])

print("\nNull Values in Each Column:")
print(data.isnull().sum())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52000 entries, 0 to 51999
# Data columns (total 26 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Location_Easting_OSGR                        52000 non-null  float64
#  1   Location_Northing_OSGR                       52000 non-null  float64
#  2   Longitude                                    52000 non-null  float64
#  3   Latitude                                     52000 non-null  float64
#  4   Police_Force                                 52000 non-null  int64
#  5   Accident_Severity                            51678 non-null  float64
#  6   Number_of_Vehicles                           52000 non-null  int64
#  7   Number_of_Casualties                         50959 non-null  float64
#  8   Date                                         52000 non-null  object
#  9   Day_of_Week                                  52000 non-null  int64
#  10  Local_Authority_(District)                   52000 non-null  int64
#  11  Local_Authority_(Highway)                    52000 non-null  object
#  12  1st_Road_Class                               52000 non-null  int64
#  13  1st_Road_Number                              52000 non-null  int64
#  14  Road_Type                                    52000 non-null  object
#  15  Speed_limit                                  52000 non-null  int64
#  16  2nd_Road_Class                               52000 non-null  int64
#  17  2nd_Road_Number                              52000 non-null  int64
#  18  Pedestrian_Crossing-Human_Control            52000 non-null  object
#  19  Pedestrian_Crossing-Physical_Facilities      52000 non-null  object
#  20  Light_Conditions                             51456 non-null  object
#  21  Weather_Conditions                           52000 non-null  object
#  22  Road_Surface_Conditions                      52000 non-null  object
#  23  Urban_or_Rural_Area                          51912 non-null  float64
#  24  Did_Police_Officer_Attend_Scene_of_Accident  52000 non-null  object
#  25  Year                                         52000 non-null  int64
# dtypes: float64(7), int64(10), object(9)
# memory usage: 10.3+ MB
# None
#
# Dataset Shape:
# (52000, 26)
#
# First Few Rows of the Dataset:
#    Location_Easting_OSGR  Location_Northing_OSGR  Longitude   Latitude  \
# 0               560530.0                103950.0   0.277298  50.812789
# 1               508860.0                187170.0  -0.430574  51.572846
# 2               314460.0                169130.0  -3.231459  51.414661
# 3               341700.0                408330.0  -2.881800  53.568318
# 4               386488.0                350090.0  -2.203020  53.047882
#
#    Police_Force  Accident_Severity  Number_of_Vehicles  Number_of_Casualties  \
# 0            47                3.0                   1                   1.0
# 1             1                3.0                   2                   1.0
# 2            62                3.0                   2                   1.0
# 3             4                3.0                   1                   2.0
# 4            21                3.0                   2                   2.0
#
#          Date  Day_of_Week  ...  2nd_Road_Class 2nd_Road_Number  \
# 0  27/11/2009            6  ...              -1               0
# 1  10/10/2010            1  ...               6               0
# 2  14/09/2005            4  ...               3            4055
# 3  18/08/2007            7  ...               6               0
# 4  06/08/2013            3  ...              -1               0
#
#    Pedestrian_Crossing-Human_Control  Pedestrian_Crossing-Physical_Facilities  \
# 0              None within 50 metres    No physical crossing within 50 meters
# 1              None within 50 metres    No physical crossing within 50 meters
# 2              None within 50 metres    No physical crossing within 50 meters
# 3              None within 50 metres    No physical crossing within 50 meters
# 4              None within 50 metres    No physical crossing within 50 meters
#
#                           Light_Conditions          Weather_Conditions  \
# 0            Darkeness: No street lighting     Raining with high winds
# 1  Darkness: Street lights present and lit     Fine without high winds
# 2           Daylight: Street light present     Fine without high winds
# 3           Daylight: Street light present  Raining without high winds
# 4           Daylight: Street light present     Fine without high winds
#
#      Road_Surface_Conditions  Urban_or_Rural_Area  \
# 0  Flood (Over 3cm of water)                  2.0
# 1                        Dry                  1.0
# 2                        Dry                  1.0
# 3                   Wet/Damp                  1.0
# 4                        Dry                  1.0
#
#   Did_Police_Officer_Attend_Scene_of_Accident  Year
# 0                                         Yes  2009
# 1                                         Yes  2010
# 2                                         Yes  2005
# 3                                         Yes  2007
# 4                                         Yes  2013
#
# [5 rows x 26 columns]
#
# Last Few Rows of the Dataset:
#        Location_Easting_OSGR  Location_Northing_OSGR  Longitude   Latitude  \
# 51995               475125.0                319380.0  -0.888006  52.766777
# 51996               456682.0                127058.0  -1.192915  51.040030
# 51997               540510.0                152250.0   0.012032  51.252055
# 51998               434720.0                334000.0  -1.485264  52.902301
# 51999               454710.0                185430.0  -1.212104  51.565050
#
#        Police_Force  Accident_Severity  Number_of_Vehicles  \
# 51995            33                3.0                   2
# 51996            44                3.0                   1
# 51997            45                3.0                   3
# 51998            30                3.0                   2
# 51999            43                3.0                   3
#
#        Number_of_Casualties        Date  Day_of_Week  ...  2nd_Road_Class  \
# 51995                   1.0  31/08/2012            6  ...               6
# 51996                   1.0  08/05/2013            4  ...              -1
# 51997                   1.0  01/11/2011            3  ...               6
# 51998                   2.0  22/07/2011            6  ...               5
# 51999                   1.0  24/05/2010            2  ...              -1
#
#       2nd_Road_Number  Pedestrian_Crossing-Human_Control  \
# 51995            6485              None within 50 metres
# 51996               0              None within 50 metres
# 51997               0              None within 50 metres
# 51998              81              None within 50 metres
# 51999               0              None within 50 metres
#
#            Pedestrian_Crossing-Physical_Facilities  \
# 51995  Pedestrian phase at traffic signal junction
# 51996        No physical crossing within 50 meters
# 51997        No physical crossing within 50 meters
# 51998        No physical crossing within 50 meters
# 51999        No physical crossing within 50 meters
#
#                      Light_Conditions          Weather_Conditions  \
# 51995  Daylight: Street light present     Fine without high winds
# 51996   Darkeness: No street lighting     Fine without high winds
# 51997  Daylight: Street light present  Raining without high winds
# 51998  Daylight: Street light present  Raining without high winds
# 51999  Daylight: Street light present     Fine without high winds
#
#        Road_Surface_Conditions  Urban_or_Rural_Area  \
# 51995                      Dry                  1.0
# 51996                      Dry                  2.0
# 51997                 Wet/Damp                  1.0
# 51998                 Wet/Damp                  1.0
# 51999                      Dry                  2.0
#
#       Did_Police_Officer_Attend_Scene_of_Accident  Year
# 51995                                         Yes  2012
# 51996                                         Yes  2013
# 51997                                         Yes  2011
# 51998                                         Yes  2011
# 51999                                         Yes  2010
#
# [5 rows x 26 columns]
#
# Random Sample of Rows:
#        Location_Easting_OSGR  Location_Northing_OSGR  Longitude   Latitude  \
# 34004               530850.0                146530.0  -0.128394  51.202944
# 31635               518880.0                298770.0  -0.247205  52.573735
# 4720                473570.0                286890.0  -0.918272  52.474960
# 11791               530280.0                185720.0  -0.122188  51.555276
# 38692               580690.0                111650.0   0.566971  50.876030
#
#        Police_Force  Accident_Severity  Number_of_Vehicles  \
# 34004            45                3.0                   2
# 31635            35                3.0                   2
# 4720             33                3.0                   2
# 11791             1                3.0                   2
# 38692            47                3.0                   2
#
#        Number_of_Casualties        Date  Day_of_Week  ...  2nd_Road_Class  \
# 34004                   5.0  07/10/2005            6  ...              -1
# 31635                   1.0  19/12/2013            5  ...               3
# 4720                    2.0  25/08/2010            4  ...               6
# 11791                   1.0  23/12/2012            1  ...               6
# 38692                   1.0  11/12/2007            3  ...              -1
#
#       2nd_Road_Number  Pedestrian_Crossing-Human_Control  \
# 34004               0              None within 50 metres
# 31635            1179              None within 50 metres
# 4720                0              None within 50 metres
# 11791               0              None within 50 metres
# 38692               0              None within 50 metres
#
#            Pedestrian_Crossing-Physical_Facilities  \
# 34004        No physical crossing within 50 meters
# 31635        No physical crossing within 50 meters
# 4720   Pedestrian phase at traffic signal junction
# 11791        No physical crossing within 50 meters
# 38692        No physical crossing within 50 meters
#
#                               Light_Conditions          Weather_Conditions  \
# 34004           Daylight: Street light present     Fine without high winds
# 31635  Darkness: Street lights present and lit  Raining without high winds
# 4720            Daylight: Street light present  Raining without high winds
# 11791  Darkness: Street lights present and lit     Fine without high winds
# 38692           Daylight: Street light present     Fine without high winds
#
#        Road_Surface_Conditions  Urban_or_Rural_Area  \
# 34004                      Dry                  2.0
# 31635                 Wet/Damp                  1.0
# 4720                  Wet/Damp                  1.0
# 11791                      Dry                  1.0
# 38692                      Dry                  1.0
#
#       Did_Police_Officer_Attend_Scene_of_Accident  Year
# 34004                                         Yes  2005
# 31635                                         Yes  2013
# 4720                                          Yes  2010
# 11791                                          No  2012
# 38692                                         Yes  2007
#
# [5 rows x 26 columns]
#
# Summary Statistics (Numerical):
#        Location_Easting_OSGR  Location_Northing_OSGR     Longitude  \
# count           52000.000000            5.200000e+04  52000.000000
# mean           440284.256846            2.998617e+05     -1.427193
# std             95109.751221            1.613624e+05      1.398249
# min             98480.000000            1.903000e+04     -6.895268
# 25%            375540.000000            1.780100e+05     -2.366190
# 50%            440950.000000            2.671800e+05     -1.391202
# 75%            523500.000000            3.981492e+05     -0.214666
# max            654960.000000            1.203900e+06      1.753632
#
#            Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# count  52000.000000  52000.000000       51678.000000        52000.000000
# mean      52.586684     30.401712           2.837145            1.834327
# std        1.453049     25.545581           0.402582            0.727856
# min       50.026153      1.000000           1.000000            1.000000
# 25%       51.487676      7.000000           3.000000            1.000000
# 50%       52.295042     30.000000           3.000000            2.000000
# 75%       53.478016     46.000000           3.000000            2.000000
# max       60.714774     98.000000           3.000000           34.000000
#
#        Number_of_Casualties   Day_of_Week  Local_Authority_(District)  \
# count          50959.000000  52000.000000                52000.000000
# mean               1.354756      4.130712                  349.542558
# std                0.855220      1.926217                  259.504721
# min                1.000000      1.000000                    1.000000
# 25%                1.000000      2.000000                  112.000000
# 50%                1.000000      4.000000                  323.000000
# 75%                1.000000      6.000000                  530.000000
# max               51.000000      7.000000                  941.000000
#
#        1st_Road_Class  1st_Road_Number   Speed_limit  2nd_Road_Class  \
# count    52000.000000     52000.000000  52000.000000    52000.000000
# mean         4.080519       997.078077     39.148558        2.672673
# std          1.428056      1806.405065     14.212826        3.205080
# min          1.000000         0.000000     15.000000       -1.000000
# 25%          3.000000         0.000000     30.000000       -1.000000
# 50%          4.000000       128.500000     30.000000        3.000000
# 75%          6.000000       716.000000     50.000000        6.000000
# max          6.000000      9999.000000     70.000000        6.000000
#
#        2nd_Road_Number  Urban_or_Rural_Area          Year
# count     52000.000000         51912.000000  52000.000000
# mean        384.503058             1.359397   2009.401788
# std        1304.989395             0.479868      3.006997
# min          -1.000000             1.000000   2005.000000
# 25%           0.000000             1.000000   2006.000000
# 50%           0.000000             1.000000   2010.000000
# 75%           0.000000             2.000000   2012.000000
# max        9999.000000             3.000000   2014.000000
#
# Summary Statistics (Categorical):
#               Date Local_Authority_(Highway)           Road_Type  \
# count        52000                     52000               52000
# unique        3286                       206                   6
# top     04/11/2005                 E10000016  Single carriageway
# freq            43                      1465               38852
#
#        Pedestrian_Crossing-Human_Control  \
# count                              52000
# unique                                 3
# top                None within 50 metres
# freq                               51718
#
#        Pedestrian_Crossing-Physical_Facilities  \
# count                                    52000
# unique                                       6
# top      No physical crossing within 50 meters
# freq                                     43368
#
#                       Light_Conditions       Weather_Conditions  \
# count                            51456                    52000
# unique                               5                        9
# top     Daylight: Street light present  Fine without high winds
# freq                             37734                    41662
#
#        Road_Surface_Conditions Did_Police_Officer_Attend_Scene_of_Accident
# count                    52000                                       52000
# unique                       6                                           2
# top                        Dry                                         Yes
# freq                     35727                                       42143
#
# Number of Duplicated Rows: 43
#
# Duplicated Rows:
#        Location_Easting_OSGR  Location_Northing_OSGR  Longitude   Latitude  \
# 8927                335170.0                389930.0  -2.976581  53.402184
# 13879               527300.0                175420.0  -0.168864  51.463390
# 20643               369510.0                427740.0  -2.463805  53.745134
# 21078               354241.0                429411.0  -2.695562  53.759033
# 22171               512770.0                178930.0  -0.376815  51.498017
# 23074               526430.0                174920.0  -0.181560  51.459091
# 24079               295133.0                665408.0  -3.677463  55.870435
# 27268               416010.0                432200.0  -1.758488  53.785876
# 29451               431348.0                581609.0  -1.509917  55.127895
# 33253               513510.0                173910.0  -0.367770  51.452749
# 34457               365551.0                399738.0  -2.520726  53.493204
# 34821               365469.0                404460.0  -2.522484  53.535641
# 35613               334533.0                427490.0  -2.994047  53.739662
# 36324               516580.0                182940.0  -0.320627  51.533286
# 36595               526940.0                174830.0  -0.174256  51.458168
# 36765               537750.0                175900.0  -0.018338  51.465258
# 37248               525110.0                189400.0  -0.195412  51.589518
# 37365               385032.0                564340.0  -2.235361  54.973469
# 37675               531220.0                161560.0  -0.117588  51.337936
# 38368               379443.0                421904.0  -2.312804  53.693168
# 38681               332811.0                442534.0  -3.023438  53.874639
# 38764               374648.0                442189.0  -2.387094  53.875277
# 39426               299300.0                527960.0  -3.561711  54.636694
# 39570               437763.0                555218.0  -1.412794  54.890303
# 40338               384517.0                432352.0  -2.236489  53.787252
# 42233               460672.0                451245.0  -1.076920  53.953750
# 42764               443100.0                425770.0  -1.348239  53.726552
# 43033               511264.0                478175.0  -0.296369  54.187288
# 43037               523770.0                187810.0  -0.215305  51.575524
# 43118               335874.0                427566.0  -2.973734  53.740512
# 43737               546960.0                171710.0   0.112417  51.425294
# 44006               354520.0                430113.0  -2.691435  53.765367
# 44341               377030.0                361940.0  -2.344956  53.154078
# 44848               332640.0                413460.0  -3.019692  53.613335
# 45502               433189.0                566556.0  -1.482794  54.992511
# 46171               437109.0                554128.0  -1.423129  54.880557
# 46653               343550.0                396880.0  -2.851802  53.465613
# 46819               363720.0                389120.0  -2.547096  53.397643
# 47312               375098.0                430460.0  -2.379296  53.769879
# 48049               372762.0                411281.0  -2.413047  53.597380
# 49249               417227.0                566494.0  -1.732274  54.992758
# 50761               420234.0                565406.0  -1.685353  54.982869
# 50811               388276.0                398742.0  -2.178157  53.485253
#
#        Police_Force  Accident_Severity  Number_of_Vehicles  \
# 8927              5                3.0                   2
# 13879             1                3.0                   1
# 20643             4                3.0                   1
# 21078             4                3.0                   1
# 22171             1                3.0                   2
# 23074             1                3.0                   2
# 24079            95                3.0                   3
# 27268            13                2.0                   1
# 29451            10                3.0                   2
# 33253             1                3.0                   2
# 34457             6                3.0                   2
# 34821             6                3.0                   2
# 35613             4                3.0                   1
# 36324             1                3.0                   2
# 36595             1                3.0                   4
# 36765             1                3.0                   1
# 37248             1                3.0                   2
# 37365            10                3.0                   4
# 37675             1                2.0                   2
# 38368             4                3.0                   2
# 38681             4                3.0                   2
# 38764             4                3.0                   2
# 39426             3                3.0                   2
# 39570            10                3.0                   3
# 40338             4                3.0                   2
# 42233            12                2.0                   1
# 42764            13                2.0                   1
# 43033            12                3.0                   2
# 43037             1                3.0                   2
# 43118             4                3.0                   1
# 43737             1                3.0                   2
# 44006             4                3.0                   1
# 44341             7                3.0                   2
# 44848             5                2.0                   2
# 45502            10                3.0                   2
# 46171            10                3.0                   2
# 46653             5                3.0                   2
# 46819             7                3.0                   2
# 47312             4                2.0                   2
# 48049             6                3.0                   2
# 49249            10                3.0                   2
# 50761            10                3.0                   2
# 50811             6                3.0                   3
#
#        Number_of_Casualties        Date  Day_of_Week  ...  2nd_Road_Class  \
# 8927                    1.0  02/06/2012            7  ...              -1
# 13879                   1.0  12/03/2012            2  ...              -1
# 20643                   1.0  11/01/2012            4  ...               3
# 21078                   1.0  29/09/2012            7  ...              -1
# 22171                   1.0  01/12/2012            7  ...               3
# 23074                   1.0  21/12/2012            6  ...               6
# 24079                   2.0  01/05/2013            4  ...              -1
# 27268                   1.0  27/01/2012            6  ...              -1
# 29451                   1.0  28/01/2012            7  ...               6
# 33253                   1.0  08/08/2012            4  ...               4
# 34457                   1.0  30/03/2012            6  ...               6
# 34821                   1.0  02/03/2012            6  ...               6
# 35613                   1.0  20/12/2012            5  ...               6
# 36324                   2.0  06/09/2012            5  ...               4
# 36595                   2.0  21/03/2012            4  ...              -1
# 36765                   1.0  27/11/2012            3  ...               6
# 37248                   2.0  22/10/2012            2  ...              -1
# 37365                   2.0  29/11/2012            5  ...               3
# 37675                   1.0  22/09/2012            7  ...               3
# 38368                   1.0  02/12/2012            1  ...               6
# 38681                   1.0  09/01/2012            2  ...               4
# 38764                   1.0  03/10/2012            4  ...              -1
# 39426                   2.0  13/12/2012            5  ...               6
# 39570                   2.0  11/12/2012            3  ...               6
# 40338                   1.0  29/01/2012            1  ...               6
# 42233                   1.0  03/07/2012            3  ...              -1
# 42764                   1.0  02/03/2012            6  ...               6
# 43033                   4.0  08/06/2012            6  ...              -1
# 43037                   1.0  17/02/2012            6  ...               6
# 43118                   1.0  26/06/2012            3  ...              -1
# 43737                   1.0  06/09/2012            5  ...               5
# 44006                   1.0  06/11/2012            3  ...              -1
# 44341                   2.0  13/11/2012            3  ...               3
# 44848                   1.0  29/11/2012            5  ...               3
# 45502                   2.0  27/09/2012            5  ...               6
# 46171                   1.0  04/11/2012            1  ...               6
# 46653                   1.0  25/01/2012            4  ...               3
# 46819                   1.0  28/06/2012            5  ...              -1
# 47312                   1.0  27/03/2012            3  ...               6
# 48049                   1.0  08/11/2012            5  ...              -1
# 49249                   4.0  16/09/2012            1  ...               4
# 50761                   2.0  17/11/2012            7  ...               3
# 50811                   1.0  02/10/2012            3  ...               6
#
#       2nd_Road_Number  Pedestrian_Crossing-Human_Control  \
# 8927                0              None within 50 metres
# 13879               0              None within 50 metres
# 20643             679              None within 50 metres
# 21078               0              None within 50 metres
# 22171            3005              None within 50 metres
# 23074               0              None within 50 metres
# 24079               0              None within 50 metres
# 27268               0              None within 50 metres
# 29451            9503              None within 50 metres
# 33253             358              None within 50 metres
# 34457               0              None within 50 metres
# 34821               0              None within 50 metres
# 35613               0              None within 50 metres
# 36324             452              None within 50 metres
# 36595               0              None within 50 metres
# 36765               0              None within 50 metres
# 37248               0              None within 50 metres
# 37365             686              None within 50 metres
# 37675              22              None within 50 metres
# 38368               0              None within 50 metres
# 38681            5412              None within 50 metres
# 38764               0              None within 50 metres
# 39426               0              None within 50 metres
# 39570            5174              None within 50 metres
# 40338               0              None within 50 metres
# 42233               0              None within 50 metres
# 42764               0              None within 50 metres
# 43033               0              None within 50 metres
# 43037               0              None within 50 metres
# 43118               0              None within 50 metres
# 43737               0              None within 50 metres
# 44006               0              None within 50 metres
# 44341            5022              None within 50 metres
# 44848             565              None within 50 metres
# 45502            2242              None within 50 metres
# 46171            5127              None within 50 metres
# 46653            5208              None within 50 metres
# 46819               0              None within 50 metres
# 47312               0              None within 50 metres
# 48049               0              None within 50 metres
# 49249            6528              None within 50 metres
# 50761             191              None within 50 metres
# 50811               0              None within 50 metres
#
#            Pedestrian_Crossing-Physical_Facilities  \
# 8927         No physical crossing within 50 meters
# 13879        No physical crossing within 50 meters
# 20643                               Zebra crossing
# 21078        No physical crossing within 50 meters
# 22171        No physical crossing within 50 meters
# 23074        No physical crossing within 50 meters
# 24079        No physical crossing within 50 meters
# 27268        No physical crossing within 50 meters
# 29451        No physical crossing within 50 meters
# 33253        No physical crossing within 50 meters
# 34457        No physical crossing within 50 meters
# 34821        No physical crossing within 50 meters
# 35613                               Zebra crossing
# 36324  Pedestrian phase at traffic signal junction
# 36595        No physical crossing within 50 meters
# 36765             non-junction pedestrian crossing
# 37248        No physical crossing within 50 meters
# 37365        No physical crossing within 50 meters
# 37675  Pedestrian phase at traffic signal junction
# 38368        No physical crossing within 50 meters
# 38681                               Central refuge
# 38764        No physical crossing within 50 meters
# 39426        No physical crossing within 50 meters
# 39570             non-junction pedestrian crossing
# 40338        No physical crossing within 50 meters
# 42233        No physical crossing within 50 meters
# 42764             non-junction pedestrian crossing
# 43033        No physical crossing within 50 meters
# 43037        No physical crossing within 50 meters
# 43118        No physical crossing within 50 meters
# 43737        No physical crossing within 50 meters
# 44006        No physical crossing within 50 meters
# 44341        No physical crossing within 50 meters
# 44848        No physical crossing within 50 meters
# 45502        No physical crossing within 50 meters
# 46171  Pedestrian phase at traffic signal junction
# 46653        No physical crossing within 50 meters
# 46819        No physical crossing within 50 meters
# 47312        No physical crossing within 50 meters
# 48049        No physical crossing within 50 meters
# 49249        No physical crossing within 50 meters
# 50761        No physical crossing within 50 meters
# 50811        No physical crossing within 50 meters
#
#                               Light_Conditions          Weather_Conditions  \
# 8927            Daylight: Street light present                     Unknown
# 13879           Daylight: Street light present     Fine without high winds
# 20643  Darkness: Street lights present and lit  Raining without high winds
# 21078  Darkness: Street lights present and lit     Fine without high winds
# 22171  Darkness: Street lights present and lit     Fine without high winds
# 23074           Daylight: Street light present     Fine without high winds
# 24079           Daylight: Street light present     Fine without high winds
# 27268  Darkness: Street lights present and lit     Fine without high winds
# 29451           Daylight: Street light present     Fine without high winds
# 33253  Darkness: Street lights present and lit     Fine without high winds
# 34457           Daylight: Street light present     Fine without high winds
# 34821           Daylight: Street light present     Fine without high winds
# 35613  Darkness: Street lights present and lit  Raining without high winds
# 36324           Daylight: Street light present     Fine without high winds
# 36595           Daylight: Street light present     Fine without high winds
# 36765  Darkness: Street lights present and lit  Raining without high winds
# 37248  Darkness: Street lights present and lit     Fine without high winds
# 37365           Daylight: Street light present     Fine without high winds
# 37675  Darkness: Street lights present and lit     Fine without high winds
# 38368           Daylight: Street light present     Fine without high winds
# 38681  Darkness: Street lights present and lit     Fine without high winds
# 38764           Daylight: Street light present  Raining without high winds
# 39426           Daylight: Street light present     Fine without high winds
# 39570  Darkness: Street lights present and lit     Fine without high winds
# 40338           Daylight: Street light present     Fine without high winds
# 42233        Darkness: Street lighting unknown     Fine without high winds
# 42764  Darkness: Street lights present and lit     Fine without high winds
# 43033           Daylight: Street light present  Raining without high winds
# 43037           Daylight: Street light present     Fine without high winds
# 43118           Daylight: Street light present     Fine without high winds
# 43737           Daylight: Street light present     Fine without high winds
# 44006           Daylight: Street light present     Fine without high winds
# 44341  Darkness: Street lights present and lit     Fine without high winds
# 44848  Darkness: Street lights present and lit     Fine without high winds
# 45502           Daylight: Street light present     Fine without high winds
# 46171  Darkness: Street lights present and lit                       Other
# 46653  Darkness: Street lights present and lit     Fine without high winds
# 46819  Darkness: Street lights present and lit     Fine without high winds
# 47312           Daylight: Street light present     Fine without high winds
# 48049  Darkness: Street lights present and lit     Fine without high winds
# 49249  Darkness: Street lights present and lit     Fine without high winds
# 50761           Daylight: Street light present     Fine without high winds
# 50811           Daylight: Street light present  Raining without high winds
#
#        Road_Surface_Conditions  Urban_or_Rural_Area  \
# 8927                       Dry                  1.0
# 13879                      Dry                  1.0
# 20643                 Wet/Damp                  1.0
# 21078                      Dry                  1.0
# 22171                      Dry                  1.0
# 23074                 Wet/Damp                  1.0
# 24079                      Dry                  1.0
# 27268                 Wet/Damp                  1.0
# 29451                 Wet/Damp                  1.0
# 33253                      Dry                  1.0
# 34457                      Dry                  1.0
# 34821                      Dry                  1.0
# 35613                 Wet/Damp                  1.0
# 36324                      Dry                  1.0
# 36595                      Dry                  1.0
# 36765                 Wet/Damp                  1.0
# 37248                      Dry                  1.0
# 37365                 Wet/Damp                  2.0
# 37675                      Dry                  1.0
# 38368                 Wet/Damp                  1.0
# 38681                      Dry                  2.0
# 38764                 Wet/Damp                  1.0
# 39426                      Dry                  1.0
# 39570                 Wet/Damp                  1.0
# 40338                 Wet/Damp                  1.0
# 42233                      Dry                  1.0
# 42764                      Dry                  1.0
# 43033                 Wet/Damp                  2.0
# 43037                      Dry                  1.0
# 43118                      Dry                  1.0
# 43737                      Dry                  1.0
# 44006                      Dry                  1.0
# 44341                      Dry                  2.0
# 44848                Frost/Ice                  1.0
# 45502                      Dry                  2.0
# 46171                Frost/Ice                  2.0
# 46653                      Dry                  2.0
# 46819                 Wet/Damp                  2.0
# 47312                      Dry                  1.0
# 48049                      Dry                  1.0
# 49249                      Dry                  2.0
# 50761                 Wet/Damp                  1.0
# 50811                 Wet/Damp                  1.0
#
#       Did_Police_Officer_Attend_Scene_of_Accident  Year
# 8927                                           No  2012
# 13879                                          No  2012
# 20643                                         Yes  2012
# 21078                                         Yes  2012
# 22171                                         Yes  2012
# 23074                                         Yes  2012
# 24079                                         Yes  2013
# 27268                                         Yes  2012
# 29451                                         Yes  2012
# 33253                                         Yes  2012
# 34457                                          No  2012
# 34821                                         Yes  2012
# 35613                                         Yes  2012
# 36324                                         Yes  2012
# 36595                                         Yes  2012
# 36765                                         Yes  2012
# 37248                                         Yes  2012
# 37365                                         Yes  2012
# 37675                                         Yes  2012
# 38368                                         Yes  2012
# 38681                                         Yes  2012
# 38764                                         Yes  2012
# 39426                                          No  2012
# 39570                                         Yes  2012
# 40338                                         Yes  2012
# 42233                                          No  2012
# 42764                                         Yes  2012
# 43033                                         Yes  2012
# 43037                                         Yes  2012
# 43118                                         Yes  2012
# 43737                                         Yes  2012
# 44006                                         Yes  2012
# 44341                                         Yes  2012
# 44848                                         Yes  2012
# 45502                                         Yes  2012
# 46171                                         Yes  2012
# 46653                                         Yes  2012
# 46819                                         Yes  2012
# 47312                                         Yes  2012
# 48049                                         Yes  2012
# 49249                                         Yes  2012
# 50761                                         Yes  2012
# 50811                                         Yes  2012
#
# [43 rows x 26 columns]
#
# Null Values in Each Column:
# Location_Easting_OSGR                             0
# Location_Northing_OSGR                            0
# Longitude                                         0
# Latitude                                          0
# Police_Force                                      0
# Accident_Severity                               322
# Number_of_Vehicles                                0
# Number_of_Casualties                           1041
# Date                                              0
# Day_of_Week                                       0
# Local_Authority_(District)                        0
# Local_Authority_(Highway)                         0
# 1st_Road_Class                                    0
# 1st_Road_Number                                   0
# Road_Type                                         0
# Speed_limit                                       0
# 2nd_Road_Class                                    0
# 2nd_Road_Number                                   0
# Pedestrian_Crossing-Human_Control                 0
# Pedestrian_Crossing-Physical_Facilities           0
# Light_Conditions                                544
# Weather_Conditions                                0
# Road_Surface_Conditions                           0
# Urban_or_Rural_Area                              88
# Did_Police_Officer_Attend_Scene_of_Accident       0
# Year                                              0
# dtype: int64

# %% [markdown]
# ## Data Preprocessing
# Do what you think you need such as:
# * Remove the outliers
# * Impute missing data
# * Scale the data
# * Reduce dimentions using PCA
# * Implement One-Hot Encoding for nominal categorical variables.

# %%
#Remove the outliers
numerical_features = ['Police_Force', 'Latitude', 'Day_of_Week']
#Impute missing data
num_features = ['type_car', 'plate_num', 'car_color']
#Scale the data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
#Reduce dimentions using PCA
from sklearn.decomposition import PCA
pca = PCA(n_components=2)

# %% [markdown]
# ## Feature Selection
# Select relevant features for clustering. Explain your choice of features.

# %%
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
data = load_iris()
X = pd.DataFrame(data.data, columns=data.feature_names)
y = data.target
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
selector = SelectKBest(score_func=f_classif, k=4)
X_train_selected = selector.fit_transform(X_train_scaled, y_train)
X_test_selected = selector.transform(X_test_scaled)

# %% [markdown]
# ## Data Visualization
# Visualize the data using appropriate plots to gain insights into the dataset. Using the following:
# - Scatter plot of accidents based on Longitude and Latitude.

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Longitude'], df['Latitude'], alpha=0.5, c='red', edgecolors='w', s=10)
plt.title('Scatter Plot of Accidents Based on Longitude and Latitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Clustering
# Apply K-Means clustering. Determine the optimal number of clusters and justify your choice.
# * Find the `n_clusters` parameter using the elbow method.
# * Train the model.

# %%
X = df[['Longitude', 'Latitude']]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

inertia = []
k_range = range(1, 11)
for k in k_range:
kmeans = KMeans(n_clusters=k, random_state=42)
kmeans.fit(X_scaled)
inertia.append(kmeans.inertia_)
plt.figure(figsize=(8, 5))
plt.plot(k_range, inertia, marker='o')
plt.title('Elbow Method for Optimal Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.xticks(k_range)
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %% [markdown]
# ## Evaluation
# Evaluate the clustering result using appropriate metrics.

# %%
from sklearn.metrics import silhouette_score

silhouette_avg = silhouette_score(X_scaled, kmeans.labels_)
print(f"Silhouette Score: {silhouette_avg:.2f}")
# Out:
# Silhouette Score: 0.46

# %% [markdown]
# ## Plot the data points with their predicted cluster center

# %%
plt.figure(figsize=(10, 8))

# %% [markdown]
# ## Exam Questions
# * **Justify Your Feature Selection:**
#    - Which features did you choose for clustering and why?
# * **Number of Clusters Choices:**
#    - How did you determine the optimal number?
# * **Evaluation:**
#    - Which metrics did you use to evaluate the clustering results, and why?
#    - How do these metrics help in understanding the effectiveness of your clustering approach?
# * **Improvements and Recommendations:**
#    - Suggest any improvements or future work that could be done with this dataset. What other methods or algorithms would you consider applying?

# %% [markdown]
# Ans 1:-
# i used clustering, I selected `Longitude` and `Latitude` as the features,hey directly inform us about the location of incidents

# %% [markdown]
# Ans 2:-
# by useing Elbow Method

# %% [markdown]
# Ans 3:-
# Silhouette Score
# Measures how similar a data point is to its own and for ssesses the average similarity ratio of each cluster with its most similar cluster.

# %% [markdown]
# Ans 4:-
# by used other clustering algorithms like DBSCAN or HDBSCAN, which can handle varying cluster shapes and densities better than K-Means.
